# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
df = pd.read_csv("D:\\dsml8\supply_test.csv")

# %%
#preprocessing test dataset

# %%
df.head()
# Out:
#    Unnamed: 0 Ware_house_ID WH_Manager_ID Location_type WH_capacity_size  \
# 0       16621     WH_116621     EID_66621         Rural            Large
# 1       16622     WH_116622     EID_66622         Rural            Large
# 2       16623     WH_116623     EID_66623         Rural            Small
# 3       16624     WH_116624     EID_66624         Rural              Mid
# 4       16625     WH_116625     EID_66625         Urban              Mid
#
#     zone WH_regional_zone  num_refill_req_l3m  transport_issue_l1y  \
# 0  North           Zone 5                   5                    0
# 1  North           Zone 5                   5                    0
# 2  North           Zone 6                   3                    0
# 3   West           Zone 4                   5                    2
# 4  North           Zone 4                   6                    0
#
#    Competitor_in_mkt  ...  electric_supply dist_from_hub  workers_num  \
# ...

# %%
col_to_drop = ["Unnamed: 0", "Ware_house_ID", "WH_Manager_ID", "wh_est_year", "approved_wh_govt_certificate", "Location_type", "flood_impacted", "flood_proof"]

# %%
df.drop(col_to_drop, axis = 1, inplace = True)

# %%
def cat_num(df):
  cat = df.select_dtypes(include=['object']).columns.tolist()
  num = df.select_dtypes(exclude=['object']).columns.tolist()
  return cat, num

# %%
cat, num = cat_num(df)

# %%
cat
# Out:
# ['WH_capacity_size', 'zone', 'WH_regional_zone', 'wh_owner_type']

# %%
df1 = df.copy()

# %%
df1 = pd.get_dummies(df1, columns=cat, drop_first=True)

# %%
df1.head()
# Out:
#    num_refill_req_l3m  transport_issue_l1y  Competitor_in_mkt  \
# 0                   5                    0                  3
# 1                   5                    0                  2
# 2                   3                    0                  3
# 3                   5                    2                  2
# 4                   6                    0                  4
#
#    retail_shop_num  distributor_num  electric_supply  dist_from_hub  \
# 0             5590               15                0            156
# 1             5856               40                1             79
# 2             4803               40                1             70
# 3             4784               15                1            255
# 4             3699               24                0            205
#
#    workers_num  storage_issue_reported_l3m  temp_reg_mach  ...  \
# 0         30.0                          24              0  ...
# ...

# %%
cat, num = cat_num(df1)

# %%
cat
# Out:
# []

# %%
df2 = df1.copy()

# %%
df2.head()
# Out:
#    num_refill_req_l3m  transport_issue_l1y  Competitor_in_mkt  \
# 0                   5                    0                  3
# 1                   5                    0                  2
# 2                   3                    0                  3
# 3                   5                    2                  2
# 4                   6                    0                  4
#
#    retail_shop_num  distributor_num  electric_supply  dist_from_hub  \
# 0             5590               15                0            156
# 1             5856               40                1             79
# 2             4803               40                1             70
# 3             4784               15                1            255
# 4             3699               24                0            205
#
#    workers_num  storage_issue_reported_l3m  temp_reg_mach  ...  \
# 0         30.0                          24              0  ...
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
col_to_scale = ["retail_shop_num", "dist_from_hub", ]

# %%
df2[col_to_scale] = scaler.fit_transform(df2[col_to_scale])

# %%
df2["workers_num"] = df2["workers_num"].fillna(0)

# %%
df2 = df2.astype(int)

# %%
test_df2 = df2.copy()

# %%
#saving my new dataset to csv

# %%
test_df2.to_csv("D:\\dsml8\\supplychain\\test_df2.csv", index=False)
